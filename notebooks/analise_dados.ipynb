# %%
# Packages

# Bibliotecas Gerais
import numpy                   as np
import pandas                  as pd
import matplotlib.pyplot       as plt
import seaborn                 as sns
import sys
import time
from scipy                     import stats

# Bibliotecas do Colab
from google.colab              import drive

#Bibliotecas de Regressão
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.preprocessing   import StandardScaler
from sklearn.svm             import SVR
from sklearn.tree            import DecisionTreeRegressor
from sklearn.linear_model    import LinearRegression, Ridge, Lasso, LassoCV, ElasticNet, ElasticNetCV, HuberRegressor, LassoLars, BayesianRidge
from sklearn.linear_model    import SGDRegressor
from sklearn.ensemble        import RandomForestRegressor, AdaBoostRegressor, GradientBoostingRegressor, ExtraTreesRegressor

# Bibliotecas de Clusterização
import scipy.cluster.hierarchy as shc
from sklearn.cluster           import KMeans
from sklearn.metrics           import silhouette_score, davies_bouldin_score,v_measure_score
from sklearn.mixture           import GaussianMixture
from sklearn.neural_network    import MLPRegressor
from sklearn.metrics           import r2_score, mean_absolute_error,mean_squared_error
from sklearn.model_selection   import GridSearchCV
from sklearn.model_selection   import RandomizedSearchCV
from sklearn.neighbors         import NearestNeighbors
from sklearn.cluster           import DBSCAN
from sklearn.cluster           import AgglomerativeClustering

# Bibliotecas Classificação
from sklearn                       import metrics
from sklearn.preprocessing         import MinMaxScaler
from sklearn.neighbors             import KNeighborsClassifier
from sklearn.linear_model          import LogisticRegression
from sklearn.tree                  import DecisionTreeClassifier
from sklearn.ensemble              import RandomForestClassifier
from sklearn.naive_bayes           import GaussianNB, MultinomialNB, ComplementNB, BernoulliNB
from sklearn.svm                   import SVC
from sklearn.neural_network        import MLPClassifier
from sklearn.metrics               import accuracy_score, precision_score, f1_score, recall_score
from sklearn.metrics               import classification_report
from sklearn.metrics               import ConfusionMatrixDisplay
from sklearn.metrics               import RocCurveDisplay

# Bibliotecas de Recomendação
from sklearn.metrics.pairwise      import cosine_similarity

# Redução de Dimensionalidade
from sklearn.decomposition         import PCA
from sklearn.decomposition         import TruncatedSVD

# %%
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
pip freeze --local > /content/gdrive/MyDrive/Arquivos_Felipe/UNIVESP/TCC/requeriments.txt

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
link   = '/content/gdrive/MyDrive/Arquivos_Felipe/UNIVESP/TCC/Dados/dados_filtrados_2014.csv'
df2014 = pd.read_csv(link,sep=",")

link   = '/content/gdrive/MyDrive/Arquivos_Felipe/UNIVESP/TCC/Dados/dados_filtrados_2015.csv'
df2015 = pd.read_csv(link,sep=",")

link   = '/content/gdrive/MyDrive/Arquivos_Felipe/UNIVESP/TCC/Dados/dados_filtrados_2016.csv'
df2016 = pd.read_csv(link,sep=",")

link   = '/content/gdrive/MyDrive/Arquivos_Felipe/UNIVESP/TCC/Dados/dados_filtrados_2017.csv'
df2017 = pd.read_csv(link,sep=",")

link   = '/content/gdrive/MyDrive/Arquivos_Felipe/UNIVESP/TCC/Dados/dados_filtrados_2018.csv'
df2018 = pd.read_csv(link,sep=",")

link   = '/content/gdrive/MyDrive/Arquivos_Felipe/UNIVESP/TCC/Dados/dados_filtrados_2019.csv'
df2019 = pd.read_csv(link,sep=",")

link   = '/content/gdrive/MyDrive/Arquivos_Felipe/UNIVESP/TCC/Dados/dados_filtrados_2020.csv'
df2020 = pd.read_csv(link,sep=",")

link   = '/content/gdrive/MyDrive/Arquivos_Felipe/UNIVESP/TCC/Dados/dados_filtrados_2021.csv'
df2021 = pd.read_csv(link,sep=",")

link   = '/content/gdrive/MyDrive/Arquivos_Felipe/UNIVESP/TCC/Dados/dados_filtrados_2022.csv'
df2022 = pd.read_csv(link,sep=",")

link   = '/content/gdrive/MyDrive/Arquivos_Felipe/UNIVESP/TCC/Dados/dados_filtrados_2023.csv'
df2023 = pd.read_csv(link,sep=",")
# Out:
# <ipython-input-28-95ed4016b16a>:2: DtypeWarning: Columns (22) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2014 = pd.read_csv(link,sep=",")
# <ipython-input-28-95ed4016b16a>:5: DtypeWarning: Columns (44,85,101) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2015 = pd.read_csv(link,sep=",")
# <ipython-input-28-95ed4016b16a>:8: DtypeWarning: Columns (6,10,18,22,44,45,46,54,64,68,74,85,101) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2016 = pd.read_csv(link,sep=",")
# <ipython-input-28-95ed4016b16a>:11: DtypeWarning: Columns (46,101) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2017 = pd.read_csv(link,sep=",")
# <ipython-input-28-95ed4016b16a>:14: DtypeWarning: Columns (45,46,101) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2018 = pd.read_csv(link,sep=",")
# ...

# %%
df2021 = df2021.rename(columns={"ANO_NASC": "DT_NASC"})
df2022 = df2022.rename(columns={"ANO_NASC": "DT_NASC"})
df2023 = df2023.rename(columns={"ANO_NASC": "DT_NASC"})

# %%
df_full = pd.concat([df2014, df2015,df2016,df2017,df2018,df2019,df2020,df2021,df2022,df2023], axis=0, ignore_index=True)

# %%
def verificacao_nulos(df_true,target_clean):

  print('=========================================================================')

  df = df_true.copy()

  target_clean_por = 100*target_clean

  names_df  = df.columns
  nnames_df = len(names_df)
  porcent_df_null = df.isnull().sum()/df.shape[0]

  for i in range(0,nnames_df):

    if(porcent_df_null[i]>target_clean):

      print('A feature %s possui mais do que %.2f porcento de dados nulos'%(names_df[i],target_clean_por))

  print('=========================================================================')

# %%
def verificacao_preenchido(df_true,target_clean):

  print('=========================================================================')

  df = df_true.copy()

  target_clean_por = 100*target_clean

  names_df  = df.columns
  nnames_df = len(names_df)
  porcent_df_null = df.isnull().sum()/df.shape[0]

  for i in range(0,nnames_df):

    if((1-porcent_df_null[i]<target_clean):

      print('A feature %s possui mais do que %.2f porcento de dados limpos'%(names_df[i],target_clean_por))

  print('=========================================================================')

# %%
target_clean = 0.7
verificacao_preenchido(df_full,target_clean)

# %%
target_clean = 0.3
verificacao_nulos(df_full,target_clean)
